# %%
#%pip install -r requirements.txt --user

# %%
from intelligent_placer_lib import intelligent_placer
import matplotlib.pyplot as plt

# %%
images = intelligent_placer.processing_source_data()

# %%
for image in images:
    
    fig, ax = plt.subplots(1, 3, figsize=(15, 6))
    ax[0].imshow(image[0], cmap='gray')
    ax[0].set_title('Input image')
    ax[1].imshow(image[1], cmap='gray')
    ax[1].set_title('Mask')
    ax[2].imshow(image[2], cmap='gray')
    ax[2].set_title('Image after mask')

# %%
images_input = intelligent_placer.processing_input_data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\GitHub\Intellegent_Placer\intelligent_placer.ipynb Cell 5' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/GitHub/Intellegent_Placer/intelligent_placer.ipynb#ch0000005?line=0'>1</a> images_input = intelligent_placer.processing_input_data(input_image_path)
#
# NameError: name 'input_image_path' is not defined

# %%
for image in images_input:
    
    fig, ax = plt.subplots(1, 3, figsize=(15, 6))
    ax[0].imshow(image[0], cmap='gray')
    ax[0].set_title('Input image')
    ax[1].imshow(image[1], cmap='gray')
    ax[1].set_title('mask')
    ax[2].imshow(image[2], cmap='gray')
    ax[2].set_title('polygon')
